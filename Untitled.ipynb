# %%
import pandas as pd
import json
import pprint

# %%
df = pd.read_csv('moviesmod1.csv')
df
# Out:
#                                        movie_title  views  item_id
# 0                                          Avatar     898        0
# 1        Pirates of the Caribbean: At World's End    2813        1
# 2                                         Spectre    1494        2
# 3                           The Dark Knight Rises    4614        3
# 4                                     John Carter     171        4
# 5                                    Spider-Man 3    1619        5
# 6                                         Tangled    3212        6
# 7                         Avengers: Age of Ultron     194        7
# 8          Harry Potter and the Half-Blood Prince    3840        8
# 9              Batman v Superman: Dawn of Justice    4276        9
# 10                               Superman Returns    3668       10
# 11                              Quantum of Solace    2854       11
# 12     Pirates of the Caribbean: Dead Man's Chest    2179       12
# ...
